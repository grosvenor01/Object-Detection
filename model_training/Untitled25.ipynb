# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-389-ge62a31b6 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %%
# !unzip -q ../dataset.zip -d ../
# Out:
# replace ../README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# !pip uninstall comet_ml
# Out:
# Found existing installation: comet-ml 3.47.4
# Uninstalling comet-ml-3.47.4:
#   Would remove:
#     /usr/local/bin/comet
#     /usr/local/lib/python3.10/dist-packages/comet_ml-3.47.4.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/comet_ml/*
# Proceed (Y/n)? y
#   Successfully uninstalled comet-ml-3.47.4

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data coco128.yaml --weights yolov5s.pt --nosave --cache
# Out:
# 2024-12-14 22:19:08.400292: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-14 22:19:08.420467: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-14 22:19:08.426385: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source ../test.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/last.pt'], source=../test.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-389-ge62a31b6 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/test.jpg: 384x640 2 objects, 26.5ms
# Speed: 0.5ms pre-process, 26.5ms inference, 716.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
